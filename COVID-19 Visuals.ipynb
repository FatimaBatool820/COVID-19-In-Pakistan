# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
x = [1,2,3]
y = [1,4,9]
plt.plot(x,y)
plt.title("Test Plot")
plt.xlabel("x")
plt.ylabel("y ")
plt.show()

# %%
data=pd.read_csv(r'F:\Semester-6\DS Covid-19\corona-virus-pakistan-dataset-2020\COVID_19.csv')

# %%
data
# Out:
#            Date Province Old  Suspected Cases Last Date  \
# 0    04/04/2020          AJK                        322
# 1    04/04/2020  Balochistan                       2171
# 2    04/04/2020           GB                        961
# 3    04/04/2020          ICT                       2395
# 4    04/04/2020           KP                       1938
# ..          ...          ...                        ...
# 233  13/05/2020           GB                       6213
# 234  13/05/2020          ICT                      20201
# 235  13/05/2020           KP                      30597
# 236  13/05/2020       Punjab                     107603
# 237  13/05/2020        Sindh                      95053
#
#      Suspected Cases Last 24 Hrs  Suspected Cases Cumulative  \
# 0                             21                         343
# 1                            230                        2401
# 2                              2                         963
# ...

# %%
data.Date
# Out:
# 0      04/04/2020
# 1      04/04/2020
# 2      04/04/2020
# 3      04/04/2020
# 4      04/04/2020
#           ...
# 233    13/05/2020
# 234    13/05/2020
# 235    13/05/2020
# 236    13/05/2020
# 237    13/05/2020
# Name: Date, Length: 238, dtype: object

# %%
data.Date.iloc[2]
# Out:
# '04/04/2020'

# %%
# More than one column can be display here
# Date and Provice or any other available column
plt.plot(data.Date,'o')
plt.plot(data.Date)
plt.show()
